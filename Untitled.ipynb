# %%
import pickle

with open('/home/byounghun/workspace/val_idx_dict.pkl', 'rb') as f:
	v = pickle.load(f)

print(len(v))
v
# Out:
# 162
# {39: 914,
#  40: 915,
#  41: 916,
#  42: 917,
#  43: 918,
#  44: 919,
#  45: 920,
#  46: 921,
#  47: 922,
#  48: 923,
#  49: 924,
#  50: 925,
#  51: 926,
#  52: 927,
#  53: 928,
#  54: 929,
#  55: 930,
#  56: 931,
#  57: 932,
#  58: 933,
#  59: 934,
#  60: 935,
#  61: 936,
#  62: 937,
#  63: 938,
#  64: 939,
#  65: 940,
#  66: 941,
#  67: 942,
#  68: 943,
#  69: 944,
#  70: 945,
#  71: 946,
#  72: 947,
#  73: 948,
#  74: 949,
#  75: 950,
#  76: 951,
#  77: 952,
#  78: 953,
#  79: 2266,
#  80: 2267,
#  81: 2268,
#  82: 2269,
#  83: 2270,
#  84: 2271,
#  85: 2272,
#  86: 2273,
#  87: 2274,
#  88: 2275,
#  89: 2276,
#  90: 2277,
#  91: 2278,
#  92: 2279,
#  93: 2280,
#  94: 2281,
#  95: 2282,
#  96: 2283,
#  97: 2284,
#  98: 2285,
#  99: 2286,
#  100: 2287,
#  101: 2288,
#  102: 2289,
#  103: 2290,
#  104: 2291,
#  105: 2292,
#  106: 2293,
#  107: 2294,
#  108: 2295,
#  109: 2296,
#  110: 2297,
#  111: 2298,
#  112: 2299,
#  113: 2300,
#  114: 2301,
#  115: 2302,
#  116: 2303,
# ...

# %%
import pickle

with open('/home/byounghun/workspace/train_idx_dict.pkl', 'rb') as f:
	t = pickle.load(f)

print(len(t))
t
# Out:
# 242
# {0: 1828,
#  1: 1829,
#  2: 1830,
#  3: 1831,
#  4: 1832,
#  5: 1833,
#  6: 1834,
#  7: 1835,
#  8: 1836,
#  9: 1837,
#  10: 1838,
#  11: 1839,
#  12: 1840,
#  13: 1841,
#  14: 1842,
#  15: 1843,
#  16: 1844,
#  17: 1845,
#  18: 1846,
#  19: 1847,
#  20: 1848,
#  21: 1849,
#  22: 1850,
#  23: 1851,
#  24: 1852,
#  25: 1853,
#  26: 1854,
#  27: 1855,
#  28: 1856,
#  29: 1857,
#  30: 1858,
#  31: 1859,
#  32: 1860,
#  33: 1861,
#  34: 1862,
#  35: 1863,
#  36: 1864,
#  37: 1865,
#  38: 1866,
#  120: 17104,
#  121: 17105,
#  122: 17106,
#  123: 17107,
#  124: 17108,
#  125: 17109,
#  126: 17110,
#  127: 17111,
#  128: 17112,
#  129: 17113,
#  130: 17114,
#  131: 17115,
#  132: 17116,
#  133: 17117,
#  134: 17118,
#  135: 17119,
#  136: 17120,
#  137: 17121,
#  138: 17122,
#  139: 17123,
#  140: 17124,
#  141: 17125,
#  142: 17126,
#  143: 17127,
#  144: 17128,
#  145: 17129,
#  146: 17130,
#  147: 17131,
#  148: 17132,
#  149: 17133,
#  150: 17134,
#  151: 17135,
#  152: 17136,
# ...
